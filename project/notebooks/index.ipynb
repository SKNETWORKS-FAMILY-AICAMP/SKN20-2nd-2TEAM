# %%
# =============================================================================
# 📊 통합 변수 분류 및 정리
# 셀 1,2,3의 내용을 분석하여 공통/개별 변수로 분류
# =============================================================================

# 🏠 1. 개인별 특성 관련 변수 (공통)
personal_characteristics = {
    'Q20A': '성별', # -> 사용 #22:dm1, 23:dm1
    'Q28': '가족구성', # -> 사용 #22:dm8 ,23:dm8 ->24년 1인가구로 명칭변경(22,23 독신가구)떻게 데이터 처리필요
    'Q86': '거주지', # ->  현재살고 있는 곳은 22,23년 모두 데이터x
    'DM2': '연령 (범주)',   # 2번셀에서만 -> 사용 #22: dm2, 23: dm2
    'DM3': '지역',          # 2번셀에서만 -> 사용 #22: dm3 23: dm3
    'DM5': '월 평균 총 가구소득', # -> 사용 #22: dm5, 23:dm5 -> 22년 400~399/500~599/600 카테고리 없음
    'DM4': '직업',          # 2번셀에서만 -> 사용 #22,23: dm6  
    'dm6': '학력',          # 2번셀에서만 -> 사용 #22,23: dm6
}

# 📱 2. 기기 이용빈도 관련 변수 (공통)
# 파생변수 2개로 축소? ex) 아날로그(TV, 라디오, 신문), 디지털(게임기, VR 제외)
# 총 7개
device_usage_frequency = {
    'q850_1': 'TV 수상기 이용빈도', # -> 사용 22: Q237A1, 23: Q237A1, 24:q850_1
    'q850_2': '라디오 이용빈도', # -> 사용 22: Q237A2, 23: Q237A2, 24:q850_2
    'q850_3': '신문 이용빈도', # -> 사용 22: Q237A3, 23: Q237A3, 24: q850_3
    'q850_4': '데스크탑PC 이용빈도', # -> 사용 22: Q237A4, 23: Q237A4, 24: q850_4
    'q850_5': '노트북 이용빈도', # -> 사용 22: Q237A5, 23: Q237A5, 24:q850_5
    'q850_6': '태블릿PC 이용빈도', # -> 사용 22: Q237A6, 23: Q237A6, 24: q850_6
    'q850_7': '스마트폰 이용빈도', # -> 사용 22: Q237A7, 23: Q237A7, 24: q850_7
}

# ⏰ 3. 시청/이용 시간 관련 변수 (공통 - 주중/주말 통합 권장)
# 일 평균 컬럼 파생변수 생성?
# 총 6개
viewing_time_variables = {
    # TV 시청시간
    'q860_t1': 'TV 일 평균 시청시간 - 주중', # -> 사용 22: Q240, 23: Q240, 24: q860_t1
    'q860_t2': 'TV 일 평균 시청시간 - 주말', # -> 사용 22: Q243, 23: Q243, 24: q860_t2
    'q870_t1': 'TV 수상기 이외의 매체 일 평균 시청시간(주중)', # -> 사용, 22: Q246, 23: Q246, 24: q870_t1
    'q870_t2': 'TV 수상기 이외의 매체 일 평균 시청시간(주말)', # -> 사용 22:Q249, 23: Q249, 24: q870_t2
    
    # OTT 이용시간  
    'q1160_t1': '일 평균 OTT 이용시간 - 주중', # -> 사용 22: Q559, 23: Q559, 24: q1160_t1
    'q1160_t2': '일 평균 OTT 이용시간 - 주말', # -> 사용 22: Q562, 23: Q562, 24: q1160_t2
    'q1180_t1': 'TV수상기를 이용한 OTT 이용시간 - 주중',  # 3번셀에서만 -> 사용불가, 22: X, 23: q1180_t1, 24:q1180_t1
    'q1180_t2': 'TV수상기를 이용한 OTT 이용시간 - 주말'   # 3번셀에서만 -> 사용불가, 22: X, 23: q1180_t1, 24:q1180_t1
}

# 📺 4. TV 시청 선호 관련 변수 (2번셀에서만)
tv_preference_variables = {
    'q920': '최근 일주일 지상파방송 시청 프로그램 유형',  # 사용 #22 Q245M_1 #23  Q245M_1
    'q1270_3': 'TV 방송시간에 맞춰 시청 선호도', # 사용 #22:Q263A3 23:Q263A3
    'q1270_4': '습관적 TV 시청 여부', # 사용 #22: Q263A4, 23: Q263A4
    'q1240_3': 'TV 놓친 프로그램 다시보기 시청' # 사용 #22,23 데이터 x
}

# 🎯 5. 시청 방식 선호도 관련 변수 (2번셀에서만)  
viewing_style_variables = {
    'q1280': '일상생활 필수 매체', # 사용 
    'q1000': '유료방송 VOD 추가요금 지불 경험', # 사용 
}

# 🎬 6. OTT 선호 관련 변수 (공통)
ott_preference_variables = {
    'q1020': '평소에 이용하는 온라인동영상서비스(OTT) 복수응답', # -> o 22: Q520M_1/ 23: Q520M_1 -> 복수응답 처리 필요, 라벨링 필요
    'q1030': '평소에 이용하는 유료 구독 OTT 서비스 복수응답',  # 1번셀 버전 -> o #22:Q551M_1, #23  Q551M_1 -> 복수응답 처리 필요, 라벨링 필요
    'q1040': 'OTT 월 이용요금',  # 2번셀에서만 -> o 22: Q509/ 23: Q523
    'q1090': 'OTT 이용빈도', # 사용 22: Q523/ 23: Q523
    'q1100': 'OTT 이용기기', # 사용 22:Q522M_1/ 23; Q522M_1
    'q1210': 'OTT로 시청한 프로그램 유형',  # 2번셀에서만 # 사용  22:Q527M_2/ 23; Q527M_1  => 24년 라벨링 변경  필요
}

# 🎯 7. 이탈률 관련 추천 변수 (2번셀에서만)
churn_related_variables = {
    'q850_1': 'TV 수상기 이용빈도 (이탈률 타겟 후보)',
    'q1560_1': 'TV프로그램 시청 (이탈률 타겟 후보)',
    'q1560_3': 'OTT 시청'  # 2번셀에서만 -> o, 22,23: Q523
}

# 📊 통합 요약 출력
print("=
,
📊 변수 분류 및 통합 정리")
print("=
,
,
,
🏠 개인별 특성", personal_characteristics),
    ("📱 기기 이용빈도", device_usage_frequency), 
    ("⏰ 시청/이용시간", viewing_time_variables),
    ("📺 TV 시청선호", tv_preference_variables),
    ("🎯 시청방식선호", viewing_style_variables),
    ("🎬 OTT 관련", ott_preference_variables),
    ("⚠️  이탈률 후보", churn_related_variables)
]

for category_name, variables in categories:
    print(f"\n{category_name} ({len(variables)}개)")
    print("-" * 60)
    for i, (var_code, var_label) in enumerate(variables.items(), 1):
        print(f"{i:2d}. {var_code:<15} : {var_label}")

print(f"\n" + "=
,
📋 총 정리된 변수: {sum(len(vars) for _, vars in categories)}개")
print(f"🔄 중복 제거 권장: 시간 관련 변수들 (주중/주말 → 평균)")
print(f"🎯 이탈률 타겟: q850_1 또는 q1560_1 권장")
print("=

# %%
# =============================================================================
# 📅 2022년도 변수명 매핑
# =============================================================================

# 🏠 1. 개인별 특성 관련 변수 (2022년)
personal_characteristics_2022 = {
    'Q20A': 'dm1',           # 성별
    'Q28': 'dm8',            # 가족구성
    'Q86': None,             # 거주지 (2022년 데이터 없음)
    'DM2': 'dm2',            # 연령 (범주)
    'DM3': 'dm3',            # 지역
    'DM5': 'dm5',            # 월 평균 총 가구소득
    'DM4': 'dm6',            # 직업
    'dm6': 'dm6',            # 학력
}

# 📱 2. 기기 이용빈도 관련 변수 (2022년)
device_usage_frequency_2022 = {
    'q850_1': 'Q237A1',      # TV 수상기 이용빈도
    'q850_2': 'Q237A2',      # 라디오 이용빈도
    'q850_3': 'Q237A3',      # 신문 이용빈도
    'q850_4': 'Q237A4',      # 데스크탑PC 이용빈도
    'q850_5': 'Q237A5',      # 노트북 이용빈도
    'q850_6': 'Q237A6',      # 태블릿PC 이용빈도
    'q850_7': 'Q237A7',      # 스마트폰 이용빈도
}

# ⏰ 3. 시청/이용 시간 관련 변수 (2022년)
viewing_time_variables_2022 = {
    'q860_t1': 'Q240',       # TV 일 평균 시청시간 - 주중
    'q860_t2': 'Q243',       # TV 일 평균 시청시간 - 주말
    'q870_t1': 'Q246',       # TV 수상기 이외의 매체 일 평균 시청시간(주중)
    'q870_t2': 'Q249',       # TV 수상기 이외의 매체 일 평균 시청시간(주말)
    'q1160_t1': 'Q559',      # 일 평균 OTT 이용시간 - 주중
    'q1160_t2': 'Q562',      # 일 평균 OTT 이용시간 - 주말
    'q1180_t1': None,        # TV수상기를 이용한 OTT 이용시간 - 주중 (2022년 데이터 없음)
    'q1180_t2': None,        # TV수상기를 이용한 OTT 이용시간 - 주말 (2022년 데이터 없음)
}

# 📺 4. TV 시청 선호 관련 변수 (2022년)
tv_preference_variables_2022 = {
    'q920': 'Q245M_1',       # 최근 일주일 지상파방송 시청 프로그램 유형
    'q1270_3': 'Q263A3',     # TV 방송시간에 맞춰 시청 선호도
    'q1270_4': 'Q263A4',     # 습관적 TV 시청 여부
    'q1240_3': None,         # TV 놓친 프로그램 다시보기 시청 (2022년 데이터 없음)
}

# 🎯 5. 시청 방식 선호도 관련 변수 (2022년)
viewing_style_variables_2022 = {
    'q1280': 'q1280',        # 일상생활 필수 매체
    'q1000': 'q1000',        # 유료방송 VOD 추가요금 지불 경험
}

# 🎬 6. OTT 선호 관련 변수 (2022년)
ott_preference_variables_2022 = {
    'q1020': 'Q520M_1',      # 평소에 이용하는 온라인동영상서비스(OTT) 복수응답
    'q1030': 'Q551M_1',      # 평소에 이용하는 유료 구독 OTT 서비스 복수응답
    'q1040': 'Q509',         # OTT 월 이용요금
    'q1090': 'Q523',         # OTT 이용빈도
    'q1100': 'Q522M_1',      # OTT 이용기기
    'q1210': 'Q527M_2',      # OTT로 시청한 프로그램 유형
}

# 🎯 7. 이탈률 관련 추천 변수 (2022년)
churn_related_variables_2022 = {
    'q850_1': 'q850_1',      # TV 수상기 이용빈도 (이탈률 타겟 후보)
    'q1560_1': 'q1530_1',    # TV프로그램 시청 (이탈률 타겟 후보)
    'q1560_3': 'Q523',       # OTT 시청
}

# 📊 2022년도 변수 요약
print("="*80)
print("📅 2022년도 변수명 매핑")
print("="*80)

categories_2022 = [
    ("🏠 개인별 특성", personal_characteristics_2022),
    ("📱 기기 이용빈도", device_usage_frequency_2022), 
    ("⏰ 시청/이용시간", viewing_time_variables_2022),
    ("📺 TV 시청선호", tv_preference_variables_2022),
    ("🎯 시청방식선호", viewing_style_variables_2022),
    ("🎬 OTT 관련", ott_preference_variables_2022),
    ("⚠️ 이탈률 후보", churn_related_variables_2022)
]

for category_name, variables in categories_2022:
    print(f"\n{category_name} ({len(variables)}개)")
    print("-" * 60)
    for i, (var_2024, var_2022) in enumerate(variables.items(), 1):
        status = "✓" if var_2022 else "✗"
        var_display = var_2022 if var_2022 else "데이터 없음"
        print(f"{status} {i:2d}. {var_2024:<15} → {var_display}")

print(f"\n" + "="*80)
available_count = sum(1 for _, vars in categories_2022 for v in vars.values() if v)
total_count = sum(len(vars) for _, vars in categories_2022)
print(f"📋 2022년 사용 가능 변수: {available_count}/{total_count}개")
print("="*80)

# %%
# =============================================================================
# 📅 2023년도 변수명 매핑
# =============================================================================

# 🏠 1. 개인별 특성 관련 변수 (2023년)
personal_characteristics_2023 = {
    'Q20A': 'dm1',           # 성별
    'Q28': 'dm8',            # 가족구성
    'Q86': None,             # 거주지 (2023년 데이터 없음)
    'DM2': 'dm2',            # 연령 (범주)
    'DM3': 'dm3',            # 지역
    'DM5': 'dm5',            # 월 평균 총 가구소득
    'DM4': 'dm6',            # 직업
    'dm6': 'dm6',            # 학력
}

# 📱 2. 기기 이용빈도 관련 변수 (2023년)
device_usage_frequency_2023 = {
    'q850_1': 'Q237A1',      # TV 수상기 이용빈도
    'q850_2': 'Q237A2',      # 라디오 이용빈도
    'q850_3': 'Q237A3',      # 신문 이용빈도
    'q850_4': 'Q237A4',      # 데스크탑PC 이용빈도
    'q850_5': 'Q237A5',      # 노트북 이용빈도
    'q850_6': 'Q237A6',      # 태블릿PC 이용빈도
    'q850_7': 'Q237A7',      # 스마트폰 이용빈도
}

# ⏰ 3. 시청/이용 시간 관련 변수 (2023년)
viewing_time_variables_2023 = {
    'q860_t1': 'Q240',       # TV 일 평균 시청시간 - 주중
    'q860_t2': 'Q243',       # TV 일 평균 시청시간 - 주말
    'q870_t1': 'Q246',       # TV 수상기 이외의 매체 일 평균 시청시간(주중)
    'q870_t2': 'Q249',       # TV 수상기 이외의 매체 일 평균 시청시간(주말)
    'q1160_t1': 'Q559',      # 일 평균 OTT 이용시간 - 주중
    'q1160_t2': 'Q562',      # 일 평균 OTT 이용시간 - 주말
    'q1180_t1': 'q1180_t1',  # TV수상기를 이용한 OTT 이용시간 - 주중
    'q1180_t2': 'q1180_t1',  # TV수상기를 이용한 OTT 이용시간 - 주말
}

# 📺 4. TV 시청 선호 관련 변수 (2023년)
tv_preference_variables_2023 = {
    'q920': 'Q245M_1',       # 최근 일주일 지상파방송 시청 프로그램 유형
    'q1270_3': 'Q263A3',     # TV 방송시간에 맞춰 시청 선호도
    'q1270_4': 'Q263A4',     # 습관적 TV 시청 여부
    'q1240_3': None,         # TV 놓친 프로그램 다시보기 시청 (2023년 데이터 없음)
}

# 🎯 5. 시청 방식 선호도 관련 변수 (2023년)
viewing_style_variables_2023 = {
    'q1280': 'q1280',        # 일상생활 필수 매체
    'q1000': 'q1000',        # 유료방송 VOD 추가요금 지불 경험
}

# 🎬 6. OTT 선호 관련 변수 (2023년)
ott_preference_variables_2023 = {
    'q1020': 'Q520M_1',      # 평소에 이용하는 온라인동영상서비스(OTT) 복수응답
    'q1030': 'Q551M_1',      # 평소에 이용하는 유료 구독 OTT 서비스 복수응답
    'q1040': 'Q523',         # OTT 월 이용요금
    'q1090': 'Q523',         # OTT 이용빈도
    'q1100': 'Q522M_1',      # OTT 이용기기
    'q1210': 'Q527M_1',      # OTT로 시청한 프로그램 유형
}

# 🎯 7. 이탈률 관련 추천 변수 (2023년)
churn_related_variables_2023 = {
    'q850_1': 'Q237A1',      # TV 수상기 이용빈도 (이탈률 타겟 후보)
    'q1560_1': 'Q419A1',     # TV프로그램 시청 (이탈률 타겟 후보)
    'q1560_3': 'Q523',       # OTT 시청
}

# 📊 2023년도 변수 요약
print("="*80)
print("📅 2023년도 변수명 매핑")
print("="*80)

categories_2023 = [
    ("🏠 개인별 특성", personal_characteristics_2023),
    ("📱 기기 이용빈도", device_usage_frequency_2023), 
    ("⏰ 시청/이용시간", viewing_time_variables_2023),
    ("📺 TV 시청선호", tv_preference_variables_2023),
    ("🎯 시청방식선호", viewing_style_variables_2023),
    ("🎬 OTT 관련", ott_preference_variables_2023),
    ("⚠️ 이탈률 후보", churn_related_variables_2023)
]

for category_name, variables in categories_2023:
    print(f"\n{category_name} ({len(variables)}개)")
    print("-" * 60)
    for i, (var_2024, var_2023) in enumerate(variables.items(), 1):
        status = "✓" if var_2023 else "✗"
        var_display = var_2023 if var_2023 else "데이터 없음"
        print(f"{status} {i:2d}. {var_2024:<15} → {var_display}")

print(f"\n" + "="*80)
available_count = sum(1 for _, vars in categories_2023 for v in vars.values() if v)
total_count = sum(len(vars) for _, vars in categories_2023)
print(f"📋 2023년 사용 가능 변수: {available_count}/{total_count}개")
print("="*80)

# %%
# =============================================================================
# 📅 2024년도 변수명 매핑
# =============================================================================

# 🏠 1. 개인별 특성 관련 변수 (2024년)
personal_characteristics_2024 = {
    'Q20A': 'Q20A',          # 성별
    'Q28': 'Q28',            # 가족구성
    'Q86': 'Q86',            # 거주지
    'DM2': 'DM2',            # 연령 (범주)
    'DM3': 'DM3',            # 지역
    'DM5': 'DM5',            # 월 평균 총 가구소득
    'DM4': 'DM4',            # 직업
    'dm6': 'dm6',            # 학력
}

# 📱 2. 기기 이용빈도 관련 변수 (2024년)
device_usage_frequency_2024 = {
    'q850_1': 'q850_1',      # TV 수상기 이용빈도
    'q850_2': 'q850_2',      # 라디오 이용빈도
    'q850_3': 'q850_3',      # 신문 이용빈도
    'q850_4': 'q850_4',      # 데스크탑PC 이용빈도
    'q850_5': 'q850_5',      # 노트북 이용빈도
    'q850_6': 'q850_6',      # 태블릿PC 이용빈도
    'q850_7': 'q850_7',      # 스마트폰 이용빈도
}

# ⏰ 3. 시청/이용 시간 관련 변수 (2024년)
viewing_time_variables_2024 = {
    'q860_t1': 'q860_t1',    # TV 일 평균 시청시간 - 주중
    'q860_t2': 'q860_t2',    # TV 일 평균 시청시간 - 주말
    'q870_t1': 'q870_t1',    # TV 수상기 이외의 매체 일 평균 시청시간(주중)
    'q870_t2': 'q870_t2',    # TV 수상기 이외의 매체 일 평균 시청시간(주말)
    'q1160_t1': 'q1160_t1',  # 일 평균 OTT 이용시간 - 주중
    'q1160_t2': 'q1160_t2',  # 일 평균 OTT 이용시간 - 주말
    'q1180_t1': 'q1180_t1',  # TV수상기를 이용한 OTT 이용시간 - 주중
    'q1180_t2': 'q1180_t2',  # TV수상기를 이용한 OTT 이용시간 - 주말
}

# 📺 4. TV 시청 선호 관련 변수 (2024년)
tv_preference_variables_2024 = {
    'q920': 'q920',          # 최근 일주일 지상파방송 시청 프로그램 유형
    'q1270_3': 'q1270_3',    # TV 방송시간에 맞춰 시청 선호도
    'q1270_4': 'q1270_4',    # 습관적 TV 시청 여부
    'q1240_3': 'q1240_3',    # TV 놓친 프로그램 다시보기 시청
}

# 🎯 5. 시청 방식 선호도 관련 변수 (2024년)
viewing_style_variables_2024 = {
    'q1280': 'q1280',        # 일상생활 필수 매체
    'q1000': 'q1000',        # 유료방송 VOD 추가요금 지불 경험
}

# 🎬 6. OTT 선호 관련 변수 (2024년)
ott_preference_variables_2024 = {
    'q1020': 'q1020',        # 평소에 이용하는 온라인동영상서비스(OTT) 복수응답
    'q1030': 'q1030',        # 평소에 이용하는 유료 구독 OTT 서비스 복수응답
    'q1040': 'q1040',        # OTT 월 이용요금
    'q1090': 'q1090',        # OTT 이용빈도
    'q1100': 'q1100',        # OTT 이용기기
    'q1210': 'q1210',        # OTT로 시청한 프로그램 유형
}

# 🎯 7. 이탈률 관련 추천 변수 (2024년)
churn_related_variables_2024 = {
    'q850_1': 'q850_1',      # TV 수상기 이용빈도 (이탈률 타겟 후보)
    'q1560_1': 'q1560_1',    # TV프로그램 시청 (이탈률 타겟 후보)
    'q1560_3': 'q1560_3',    # OTT 시청
}

# 📊 2024년도 변수 요약
print("="*80)
print("📅 2024년도 변수명 매핑")
print("="*80)

categories_2024 = [
    ("🏠 개인별 특성", personal_characteristics_2024),
    ("📱 기기 이용빈도", device_usage_frequency_2024), 
    ("⏰ 시청/이용시간", viewing_time_variables_2024),
    ("📺 TV 시청선호", tv_preference_variables_2024),
    ("🎯 시청방식선호", viewing_style_variables_2024),
    ("🎬 OTT 관련", ott_preference_variables_2024),
    ("⚠️ 이탈률 후보", churn_related_variables_2024)
]

for category_name, variables in categories_2024:
    print(f"\n{category_name} ({len(variables)}개)")
    print("-" * 60)
    for i, (var_key, var_2024) in enumerate(variables.items(), 1):
        print(f"✓ {i:2d}. {var_key:<15} → {var_2024}")

print(f"\n" + "="*80)
total_count = sum(len(vars) for _, vars in categories_2024)
print(f"📋 2024년 사용 가능 변수: {total_count}/{total_count}개")
print("="*80)
